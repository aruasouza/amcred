# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_feather('Relatório.feather')

# %%
df.head()
# Out:
#    Código Cliente             Atividade Gênero Data Nascimento PF/PJ  \
# 0           58480  AUXILIAR DE PRODUÇÃO      M      1977-11-16     F
# 1           47344           ENCARREGADO      M      1989-09-28     F
# 2           47344           ENCARREGADO      M      1989-09-28     F
# 3           56583  AUXILIAR DE PRODUÇÃO      M      2002-02-18     F
# 4           56763              PEDREIRO      M      2000-01-30     F
#
#       Contrato Data Solicitação Data Liberação/Cancelamento  \
# 0  20210611-02       2021-06-11                  2021-06-16
# 1  20190313-02       2019-03-15                  2019-03-25
# 2  20210303-09       2021-03-04                  2021-03-12
# 3  20201223-01       2020-12-23                  2020-12-30
# 4  20210113-01       2021-01-14                  2021-01-19
#
#   Primeiro Vencimento Ultimo Vencimento  ...  Garantia  Formação Escolar  \
# 0          2021-07-15        2023-02-15  ...      Aval     Sem Instrução
# ...
